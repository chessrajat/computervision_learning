# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import cv2

# %%
img = cv2.imread("../DATA/00-puppy.jpg")

# %%
type(img)
# Out:
# numpy.ndarray

# %%
plt.imshow(img)

# %%
# opencv (BGR) and matplotlib (RGB) expect different channels for RGB

# %%
# changing the channel in cv2
f_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(f_img)

# %%
img_gray = cv2.imread("../DATA/00-puppy.jpg",cv2.IMREAD_GRAYSCALE)
print(img_gray.shape)
plt.imshow(img_gray, cmap="gray")
# Out:
# (1300, 1950)

# %%
# Resizing, flipping and save images

# %%
img.shape
# Out:
# (1300, 1950, 3)

# %%
img_500_850 = cv2.resize(img,(850,400))

# %%
plt.imshow(img_500_850)

# %%
w_ratio = 0.5
h_ratio = 0.5

# %%
img_05 = cv2.resize(img,(0,0),img,w_ratio,h_ratio)

# %%
plt.imshow(img_05)

# %%
img_05.shape
# Out:
# (650, 975, 3)

# %%
img_flip = cv2.flip(img,0)
plt.imshow(img_flip)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
cv2.imwrite("../DATA/00-puppy_BGR.jpg", img)
# Out:
# True

# %%
cv2.imshow("puppy",img_05)
cv2.waitKey()
# Out:
# -1
